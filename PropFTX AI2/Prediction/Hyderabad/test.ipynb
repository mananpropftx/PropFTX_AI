# %%
import pickle

# Open the file in binary read mode
with open('C:\\Users\\Administrator\\Downloads\\PropFTX AI2\\PropFTX AI2\\Prediction\\Hyderabad\\Hyderabad_locality_encoding.pkl', 'rb') as file:
    data = pickle.load(file)

# Use the unpickled data
print(data)
# Out:
# ['AS Rao Nagar' 'Adibatla' 'Alkapur Township' 'Alwal' 'Alwal Road'
#  'Ameenpur' 'Ameenpur Road' 'Appa Junction Area' 'Attapur'
#  'Attapur Main Road' 'Bachupally' 'Bahadurpally' 'Balaji Nagar Main Road'
#  'Balanagar Main Road' 'Bandlaguda Jagir' 'Bandlaguda Jagir Road'
#  'Banjara Hills ' 'Beeramguda Main Road' 'Beeramguda Ramachandrapuram'
#  'Begumpet' 'Boduppal' 'Bolarum' 'Chakripuram Road' 'Chanda Nagar'
#  'Dilsukhnagar' 'Financial District' 'Gachibowli'
#  'Gachibowli Kondapur Road' 'Gachibowli Miyapur Road' 'Gachibowli Road'
#  'Gajularamaram' 'Gandi Maisamma' 'Gandipet' 'Ghatkesar' 'Gopanpalle'
#  'Gundlapochampally' 'HUDA Layout Nalagandla' 'Hafeezpet'
#  'Hill Country Road' 'Himayatnagar' 'Hitech City' 'Isnapur' 'JNTU Road'
#  'Jeedimetla' 'Jubilee Hills ' 'Kanchi Gachibowli Road' 'Kapra'
#  'Kavadiguda' 'Khajaguda' 'Kismatpur' 'Kokapet' 'Kollur' 'Kompally'
#  'Kondapur' 'Kothaguda' 'Kothapet' 'Kowkoor Main Road' 'Kukatpally'
# ...

# %%
import pickle

# Open the file in binary read mode to unpickle it
with open('C:\\Users\\Administrator\\Downloads\\PropFTX AI2\\PropFTX AI2\\Prediction\\Hyderabad\\Hyderabad_locality_encoding.pkl', 'rb') as file:
    data = pickle.load(file)

# Print the unpickled data (optional)
print(data)

# Save the data to a txt file
with open('localities.txt', 'w') as f:
    for item in data:
        f.write(f"{item}\n")  # Write each locality on a new line

print("Data has been saved to 'localities.txt'")
# Out:
# ['AS Rao Nagar' 'Adibatla' 'Alkapur Township' 'Alwal' 'Alwal Road'
#  'Ameenpur' 'Ameenpur Road' 'Appa Junction Area' 'Attapur'
#  'Attapur Main Road' 'Bachupally' 'Bahadurpally' 'Balaji Nagar Main Road'
#  'Balanagar Main Road' 'Bandlaguda Jagir' 'Bandlaguda Jagir Road'
#  'Banjara Hills ' 'Beeramguda Main Road' 'Beeramguda Ramachandrapuram'
#  'Begumpet' 'Boduppal' 'Bolarum' 'Chakripuram Road' 'Chanda Nagar'
#  'Dilsukhnagar' 'Financial District' 'Gachibowli'
#  'Gachibowli Kondapur Road' 'Gachibowli Miyapur Road' 'Gachibowli Road'
#  'Gajularamaram' 'Gandi Maisamma' 'Gandipet' 'Ghatkesar' 'Gopanpalle'
#  'Gundlapochampally' 'HUDA Layout Nalagandla' 'Hafeezpet'
#  'Hill Country Road' 'Himayatnagar' 'Hitech City' 'Isnapur' 'JNTU Road'
#  'Jeedimetla' 'Jubilee Hills ' 'Kanchi Gachibowli Road' 'Kapra'
#  'Kavadiguda' 'Khajaguda' 'Kismatpur' 'Kokapet' 'Kollur' 'Kompally'
#  'Kondapur' 'Kothaguda' 'Kothapet' 'Kowkoor Main Road' 'Kukatpally'
# ...
