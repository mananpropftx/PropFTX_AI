# %%
import pandas as pd

# %%
df = pd.read_csv('C:\\Users\\Administrator\\Downloads\\PropFTX AI2\\PropFTX AI2\\Bangalore_re_Data.csv.csv')

# %%
df
# Out:
#                Locality Average Property Age (in years)  Vacancy Rate (%)  \
# 0    100 Feet Ring Road                              15              12.0
# 1           Rajajinagar                              20               8.0
# 2           Thanisandra                            5-10              18.0
# 3             Jalahalli                              15              20.0
# 4          Channasandra                           10-15              25.0
# ..                  ...                             ...               ...
# 994                 NaN                             NaN               NaN
# 995                 NaN                             NaN               NaN
# 996                 NaN                             NaN               NaN
# 997                 NaN                             NaN               NaN
# 998                 NaN                             NaN               NaN
#
#      Occupancy Rate (%)                                   Economic  Factor  \
# ...

# %%
df.drop(columns=['Average Property Age (in years)','Vacancy Rate (%)','Occupancy Rate (%)','Demand-Supply Ratio','Standard Deviation (?)', 'Risk ( Weighted)'],inplace=True)

# %%
df.dropna()
# Out:
#                Locality                                   Economic  Factor
# 0    100 Feet Ring Road  Proximity to key hubs but high property prices...
# 1           Rajajinagar  Well-established residential area with strong ...
# 2           Thanisandra  High growth potential but dependent on complet...
# 3             Jalahalli  Affordable housing with steady demand and good...
# 4          Channasandra  Emerging area with limited infrastructure but ...
# ..                  ...                                                ...
# 261         Kodigehalli  High demand and well-connected area, benefitin...
# 262  Belathur Main Road  Limited demand, underdeveloped area with gaps ...
# 263       Kasavanahalli  Well-established residential locality with dem...
# 264      Vidyaranyapura  Developing area with moderate demand, though l...
# 265      Horamavu Agara  Growing residential demand with some infrastru...
#
# [266 rows x 2 columns]

# %%
df.columns = df.columns.str.strip()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 999 entries, 0 to 998
# Data columns (total 2 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Locality          266 non-null    object
#  1   Economic  Factor  266 non-null    object
# dtypes: object(2)
# memory usage: 15.7+ KB

# %%
sentence = df.iloc[1, df.columns.get_loc('Economic  Factor')]
print(sentence)
# Out:
# Well-established residential area with strong infrastructure and amenities.

# %%
import nltk
print(nltk.data.path)
# Out:
# ['C:\\Users\\Administrator/nltk_data', 'c:\\Users\\Administrator\\AppData\\Local\\Programs\\Python\\Python313\\nltk_data', 'c:\\Users\\Administrator\\AppData\\Local\\Programs\\Python\\Python313\\share\\nltk_data', 'c:\\Users\\Administrator\\AppData\\Local\\Programs\\Python\\Python313\\lib\\nltk_data', 'C:\\Users\\Administrator\\AppData\\Roaming\\nltk_data', 'C:\\nltk_data', 'D:\\nltk_data', 'E:\\nltk_data']

# %%
import os
print(os.getcwd())
# Out:
# c:\Users\Administrator\Downloads\PropFTX AI2\PropFTX AI2

# %%
import nltk
nltk.data.path.append('c:\\Users\\Administrator\\Downloads\\PropFTX AI2\\PropFTX AI2')

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Administrator\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
import nltk
import pandas as pd
from nltk.sentiment import SentimentIntensityAnalyzer
nltk.download('vader_lexicon')
sia = SentimentIntensityAnalyzer()
def clean_text(text):
    if not isinstance(text, str):
        return ""
    return text
df['Economic  Factor'] = df['Economic  Factor'].apply(clean_text)
def get_sentiment(text):
    sentiment = sia.polarity_scores(text)
    return sentiment['compound']
df['Sentiment Score'] = df['Economic  Factor'].apply(get_sentiment)
def classify_sentiment(score):
    if score > 0.1:
        return 'Positive'
    elif score < -0.1:
        return 'Negative'
    else:
        return 'Neutral'
df['Sentiment'] = df['Sentiment Score'].apply(classify_sentiment)
print(df)
# Out:
#                Locality                                   Economic  Factor  \
# 0    100 Feet Ring Road  Proximity to key hubs but high property prices...
# 1           Rajajinagar  Well-established residential area with strong ...
# 2           Thanisandra  High growth potential but dependent on complet...
# 3             Jalahalli  Affordable housing with steady demand and good...
# 4          Channasandra  Emerging area with limited infrastructure but ...
# ..                  ...                                                ...
# 994                 NaN
# 995                 NaN
# 996                 NaN
# 997                 NaN
# 998                 NaN
#
#      Sentiment Score Sentiment
# 0            -0.1901  Negative
# 1             0.5106  Positive
# 2             0.2023  Positive
# 3             0.3400  Positive
# 4            -0.1154  Negative
# ..               ...       ...
# 994           0.0000   Neutral
# 995           0.0000   Neutral
# ...

# %%
df.dropna()
# Out:
#                Locality                                   Economic  Factor  \
# 0    100 Feet Ring Road  Proximity to key hubs but high property prices...
# 1           Rajajinagar  Well-established residential area with strong ...
# 2           Thanisandra  High growth potential but dependent on complet...
# 3             Jalahalli  Affordable housing with steady demand and good...
# 4          Channasandra  Emerging area with limited infrastructure but ...
# ..                  ...                                                ...
# 261         Kodigehalli  High demand and well-connected area, benefitin...
# 262  Belathur Main Road  Limited demand, underdeveloped area with gaps ...
# 263       Kasavanahalli  Well-established residential locality with dem...
# 264      Vidyaranyapura  Developing area with moderate demand, though l...
# 265      Horamavu Agara  Growing residential demand with some infrastru...
#
#      Sentiment Score Sentiment
# 0            -0.1901  Negative
# ...

# %%
df.to_csv('Economic FactorS Sentiment Analysis.csv')
